# %%
b = 8
print(b)
# Out:
# 8

# %%
def somme(a, b):
    return a + b   

print(somme(3, 4))
# Out:
# 7

# %%
def multiply(a, b):
    return a * b


print(multiply(3, 4))
# Out:
# 12

# %%
def soustract(a, b):
    return a - b
print(soustract(3, 4))
# Out:
# -1
